# %% [markdown]
# # Snowboarding Insights
# The snowboard dataset (snowboard.csv) was obtained from: https://www.kaggle.com/datasets/oznbgcvn/snowboardpowdervalue

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
snowboard_data = pd.read_csv('snowboard.csv')
snowboard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           391 non-null    object
#  1   Model           391 non-null    object
#  2   Riding Style    391 non-null    object
#  3   Riding Level    391 non-null    object
#  4   Shape           391 non-null    object
#  5   Camber Profile  391 non-null    object
#  6   Stance          391 non-null    object
#  7   Flex            391 non-null    object
#  8   Price($)        391 non-null    int64
#  9   Powder          391 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 30.7+ KB

# %% [markdown]
# ## Snowboard Brands

# %%
brands = snowboard_data['Brand'].unique()
brands
# Out:
# array(['Nidecker', 'K2', 'Ride', 'Salomon', 'Never', 'Yes', 'Capita',
#        'Cardiff', 'Jones', 'Burton ', 'Gnu', 'Alloy', 'Tahoe', 'Soul',
#        'Osin', 'Elevated', 'Arbor', 'Nitro', 'Lib Tech', 'Rossignol',
#        'Rome', 'Prior', 'Korua', 'Rome ', 'Telos', 'Weston', 'Stone',
#        'Decathlon', 'Borealish', 'Season', 'SnoPlanks', 'Gilson', 'Niche',
#        'Moss', 'Bataleon', 'Lobster', 'Endeavor', 'Gentemstick',
#        'Dinosaurs', 'Slash', 'Sims', 'DC', 'Loaded', 'Burton', 'Never '],
#       dtype=object)

# %% [markdown]
# *Note the whitespace in some of the brand names, which needs to be removed.*

# %%
snowboard_data['Brand'] = snowboard_data['Brand'].str.strip() # remove whitespace

unique_brands = snowboard_data['Brand'].unique()
unique_brands
# Out:
# array(['Nidecker', 'K2', 'Ride', 'Salomon', 'Never', 'Yes', 'Capita',
#        'Cardiff', 'Jones', 'Burton', 'Gnu', 'Alloy', 'Tahoe', 'Soul',
#        'Osin', 'Elevated', 'Arbor', 'Nitro', 'Lib Tech', 'Rossignol',
#        'Rome', 'Prior', 'Korua', 'Telos', 'Weston', 'Stone', 'Decathlon',
#        'Borealish', 'Season', 'SnoPlanks', 'Gilson', 'Niche', 'Moss',
#        'Bataleon', 'Lobster', 'Endeavor', 'Gentemstick', 'Dinosaurs',
#        'Slash', 'Sims', 'DC', 'Loaded'], dtype=object)

# %%
brand_counts = snowboard_data['Brand'].value_counts()
brand_counts
# Out:
# Brand
# Lib Tech       35
# Burton         32
# Capita         25
# Never          23
# Yes            22
# Gnu            19
# Jones          18
# Ride           18
# Rossignol      13
# K2             12
# Arbor          12
# Korua          11
# Rome           10
# Gentemstick    10
# Nitro          10
# Salomon        10
# Endeavor        9
# Soul            9
# Cardiff         8
# Niche           7
# Stone           7
# Decathlon       6
# Weston          6
# Prior           6
# Moss            5
# Slash           5
# Nidecker        5
# Elevated        5
# Alloy           5
# Bataleon        4
# DC              4
# Borealish       3
# SnoPlanks       3
# Season          2
# Gilson          2
# Lobster         2
# Tahoe           2
# Sims            2
# Telos           1
# Osin            1
# Dinosaurs       1
# Loaded          1
# Name: count, dtype: int64

# %% [markdown]
# This project focuses on the following brands:
# - Arbor
# - Burton
# - Capita
# - GNU
# - Jones
# - Lib Tech
# - K2
# - Rome
# - Salomon
#
# *These brands were selected by the analyst based on snowboard brands of interest.*

# %%
brands_of_interest= ['Arbor', 'Burton', 'Capita', 'Gnu', 'Jones',
                     'Lib Tech', 'K2', 'Rome', 'Salomon']

snowboards = snowboard_data[snowboard_data['Brand'].isin(brands_of_interest)]

# %% [markdown]
# ### Types of Riding Styles

# %%
riding_styles = snowboards['Riding Style'].unique()
riding_styles
# Out:
# array(['Freeride', 'Snowsurf', 'All Mountain', 'Alternative Freeride',
#        'Powder', 'Freestyle', 'All Mountain Freestyle'], dtype=object)

# %% [markdown]
# This project focuses on the following riding styles:
# - All Mountain
# - Alternative Freeride
# - Freeride
# - Powder
# - Snowsurf
#
# *These brands were selected by the analyst based on interest in specific riding styles.*

# %%
riding_styles_of_interest = ['All Mountain', 'Alternative Freeride', 'Freeride', 'Powder']

snowboards = snowboards[snowboards['Riding Style'].isin(riding_styles_of_interest)]

# %%
snowboards.head()
# Out:
#      Brand            Model          Riding Style         Riding Level  \
# 1       K2       Instrument              Freeride  Intermediate-Expert
# 3       K2        Alchemist              Freeride      Advanced-Expert
# 7   Capita        Mega Merc          All Mountain  Intermediate-Expert
# 10  Capita  Indoor Survival          All Mountain  Intermediate-Expert
# 14   Jones    Mind Expander  Alternative Freeride      Advanced-Expert
#
#                   Shape      Camber Profile           Stance          Flex  \
# 1   Tapered Directional  Directional Camber    Setback -20mm  Medium/Stiff
# 3   Tapered Directional  Directional Camber    Setback -20mm  Medium/Stiff
# 7               Twinish       Hybrid Camber  Setback -12.5mm        Medium
# 10     Directional Twin       Mostly Camber  Setback -12.5mm        Medium
# 14  Tapered Directional   Continuous Rocker         Centered        Medium
#
#     Price($)   Powder
# 1        529    Great
# 3        699     Good
# 7        799  Average
# 10       549  Average
# 14       599    Great

# %%
snowboards.to_excel('snowboards.xlsx', index=False)
print('Save Successful! :)')
# Out:
# Save Successful! :)

# %% [markdown]
# -----

# %% [markdown]
# ## All Mountain Snowboards

# %%
all_mountain_boards = snowboards[snowboards['Riding Style'] == 'All Mountain']
all_mountain_boards
# Out:
#         Brand                    Model  Riding Style         Riding Level  \
# 7      Capita                Mega Merc  All Mountain  Intermediate-Expert
# 10     Capita          Indoor Survival  All Mountain  Intermediate-Expert
# 15     Burton          Custom X Camber  All Mountain               Expert
# 16     Burton            Custom Camber  All Mountain  Intermediate-Expert
# 17        Gnu              Antigravity  All Mountain      Advanced-Expert
# 20     Burton        Territory Manager  All Mountain      Advanced-Expert
# 34        Gnu        Essential Service  All Mountain      Beginner-Expert
# 45       Rome                  Freaker  All Mountain      Advanced-Expert
# 58       Rome                   Warden  All Mountain      Advanced-Expert
# 63       Rome            Stale Crewzer  All Mountain      Advanced-Expert
# 64       Rome                 National  All Mountain  Intermediate-Expert
# 71      Arbor              Coda Camber  All Mountain      Beginner-Expert
# 81     Burton             Cartographer  All Mountain      Advanced-Expert
# 93      Jones       Mind Expander Twin  All Mountain  Intermediate-Expert
# 94      Jones              Aviator 2.0  All Mountain      Advanced-Expert
# 136     Jones      Ultra Mountain Twin  All Mountain  Intermediate-Expert
# 137     Jones            Mountain Twin  All Mountain      Beginner-Expert
# 141     Arbor  Bryan Iguchi Pro Camber  All Mountain  Intermediate-Expert
# 155    Burton        3D Killroy Camber  All Mountain  Intermediate-Expert
# 164       Gnu               Billy Goat  All Mountain      Advanced-Expert
# 195  Lib Tech          Terrain Wrecker  All Mountain      Beginner-Expert
# 237    Capita                Warpspeed  All Mountain      Advanced-Expert
# 238    Capita                Supernova  All Mountain      Advanced-Expert
# 268     Jones                 Frontier  All Mountain      Beginner-Expert
# 280  Lib Tech                 Magic BM  All Mountain      Beginner-Expert
# 281       Gnu                        4  All Mountain      Advanced-Expert
# 282  Lib Tech                   Dynamo  All Mountain      Advanced-Expert
# 324   Salomon             Assassin Pro  All Mountain  Intermediate-Expert
# 333    Burton        Custom X Flying V  All Mountain  Intermediate-Expert
# 339  Lib Tech             Skunk Ape HP  All Mountain      Beginner-Expert
# 340     Jones                 Explorer  All Mountain      Beginner-Expert
# 342  Lib Tech       Travis Rice Climax  All Mountain      Advanced-Expert
# 343  Lib Tech  Travis Rice Gold Member  All Mountain      Advanced-Expert
# 346  Lib Tech            Lando Phoenix  All Mountain      Beginner-Expert
# 358       Gnu                    Money  All Mountain      Beginner-Expert
# 375    Capita                  Mercury  All Mountain  Intermediate-Expert
# 381        K2                 Manifest  All Mountain  Intermediate-Expert
# 382        K2                   Raygun  All Mountain      Beginner-Expert
# 390  Lib Tech            Attack Banana  All Mountain      Beginner-Expert
#
#                    Shape      Camber Profile             Stance          Flex  \
# 7                Twinish       Hybrid Camber    Setback -12.5mm        Medium
# 10      Directional Twin       Mostly Camber    Setback -12.5mm        Medium
# 15           Directional  Traditional Camber    Setback -12.5mm  Medium/Stiff
# 16               Twinish  Traditional Camber    Setback -12.5mm        Medium
# 17   Tapered Directional       Mostly Camber  Setback over 20mm   Medium/Soft
# 20   Tapered Directional  Directional Camber    Setback -12.5mm  Medium/Stiff
# 34               Twinish       Hybrid Rocker    Setback -12.5mm        Medium
# 45      Directional Twin       Mostly Camber           Centered        Medium
# 58      Directional Twin       Mostly Camber           Centered        Medium
# 63      Directional Twin       Mostly Camber           Centered        Medium
# 64      Directional Twin       Mostly Camber           Centered        Medium
# 71      Directional Twin       Mostly Camber           Centered        Medium
# 81   Tapered Directional  Directional Camber  Setback over 20mm        Medium
# 93      Directional Twin       Hybrid Camber           Centered        Medium
# 94               Twinish  Traditional Camber      Setback -20mm  Medium/Stiff
# 136     Directional Twin       Hybrid Camber           Centered  Medium/Stiff
# 137     Directional Twin       Hybrid Camber           Centered        Medium
# 141  Tapered Directional       Mostly Camber           Centered  Medium/Stiff
# 155          Directional       Hybrid Camber    Setback -12.5mm   Medium/Soft
# 164          Directional       Mostly Camber      Setback -20mm        Medium
# 195     Directional Twin       Hybrid Rocker           Centered        Medium
# 237          Directional  Directional Camber    Setback -12.5mm  Medium/Stiff
# 238          Directional  Directional Camber    Setback -12.5mm        Medium
# 268          Directional       Hybrid Camber  Setback over 20mm  Medium/Stiff
# 280          Directional       Hybrid Rocker  Setback over 20mm        Medium
# 281  Tapered Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 282  Tapered Directional       Mostly Camber  Setback over 20mm        Medium
# 324     Directional Twin       Hybrid Camber           Centered        Medium
# 333          Directional       Hybrid Rocker    Setback -12.5mm  Medium/Stiff
# 339     Directional Twin       Hybrid Rocker    Setback -12.5mm        Medium
# 340          Directional       Hybrid Camber  Setback over 20mm        Medium
# 342          Directional       Hybrid Rocker      Setback -20mm  Medium/Stiff
# 343          Directional       Hybrid Rocker      Setback -20mm  Medium/Stiff
# 346              Twinish       Hybrid Rocker  Setback over 20mm  Medium/Stiff
# 358     Directional Twin       Hybrid Rocker    Setback -12.5mm        Medium
# 375          Directional       Hybrid Camber    Setback -12.5mm        Medium
# 381              Twinish       Hybrid Camber      Setback -20mm  Medium/Stiff
# 382     Directional Twin      Flat to Rocker      Setback -20mm        Medium
# 390     Directional Twin       Hybrid Rocker           Centered        Medium
#
#      Price($)   Powder
# 7         799  Average
# 10        549  Average
# 15       1549     Poor
# 16        659  Average
# 17        479  Average
# 20        659     Good
# 34        499  Average
# 45        459     Poor
# 58        399  Average
# 63        499     Poor
# 64        599  Average
# 71        549     Poor
# 81        469     Good
# 93        549     Good
# 94        599  Average
# 136       599  Average
# 137       499  Average
# 141       599  Average
# 155       469  Average
# 164       619     Good
# 195       519  Average
# 237       599     Good
# 238       499  Average
# 268       489     Good
# 280       699     Good
# 281       599  Average
# 282       489     Good
# 324       549  Average
# 333       749  Average
# 339       559  Average
# 340       449     Good
# 342       969  Average
# 343       749  Average
# 346       599  Average
# 358       349  Average
# 375       549  Average
# 381       529     Good
# 382       399  Average
# 390       589  Average

# %%
all_mountain_shapes = pd.DataFrame(all_mountain_boards['Shape'].value_counts())

# %%
plt.figure(figsize=(10,6))
all_mountain_shapes.plot(kind='bar', color='#0bb5d3')
plt.title('All Mountain Snowboard Shapes')
plt.xlabel('')
plt.ylabel('Number of Boards')
# Out:
# Text(0, 0.5, 'Number of Boards')

# %% [markdown]
# Many mountain boards are directional and designed with a twin shape.

# %%
all_mountain_camber = all_mountain_boards['Camber Profile'].value_counts()
all_mountain_camber
# Out:
# Camber Profile
# Mostly Camber         11
# Hybrid Camber         10
# Hybrid Rocker         10
# Directional Camber     4
# Traditional Camber     3
# Flat to Rocker         1
# Name: count, dtype: int64

# %% [markdown]
# Majority of the all mountain boards are camber while others are rocker.

# %%
all_mountain_flex = all_mountain_boards['Flex'].value_counts()
all_mountain_flex
# Out:
# Flex
# Medium          24
# Medium/Stiff    13
# Medium/Soft      2
# Name: count, dtype: int64

# %% [markdown]
# Majority of all mountain boards have a medium flex.

# %% [markdown]
# ## Alternative Freeride Snowboards

# %%
alternative_fr_boards = snowboards[snowboards['Riding Style'] == 'Alternative Freeride']
alternative_fr_boards
# Out:
#         Brand                          Model          Riding Style  \
# 14      Jones                  Mind Expander  Alternative Freeride
# 43    Salomon                      Dancehaul  Alternative Freeride
# 59       Rome                    Service Dog  Alternative Freeride
# 65   Lib Tech                           Orca  Alternative Freeride
# 66       Rome                     Stale Fish  Alternative Freeride
# 68   Lib Tech                      Apex Orca  Alternative Freeride
# 80        Gnu                        Gremlin  Alternative Freeride
# 86     Burton                   Show Stopper  Alternative Freeride
# 133     Jones            Ultra Mind Expander  Alternative Freeride
# 134     Jones                      Lone Wolf  Alternative Freeride
# 138     Jones                     Ultracraft  Alternative Freeride
# 139     Jones                     Hovercraft  Alternative Freeride
# 156    Burton             Killroy Pow Camber  Alternative Freeride
# 157    Burton                       Big Gulp  Alternative Freeride
# 159  Lib Tech                     Short Wide  Alternative Freeride
# 161  Lib Tech             Lost Quiver Killer  Alternative Freeride
# 162       Gnu                         Nuzoid  Alternative Freeride
# 182       Gnu                        Fun Guy  Alternative Freeride
# 197        K2               Simple Pleasures  Alternative Freeride
# 198        K2                      Overboard  Alternative Freeride
# 199        K2                     Joy Driver  Alternative Freeride
# 224   Salomon                     HPS x Asmo  Alternative Freeride
# 266    Burton                     One-Hitter  Alternative Freeride
# 270  Lib Tech                    Lost Rocket  Alternative Freeride
# 273  Lib Tech                      Stump Ape  Alternative Freeride
# 299     Arbor                           Cask  Alternative Freeride
# 321   Salomon                  SickStick 151  Alternative Freeride
# 322      Rome             Powder Division MT  Alternative Freeride
# 334    Burton                       Stun Gun  Alternative Freeride
# 356       Gnu  Super Progressive Air Machine  Alternative Freeride
# 380        K2                   Eighty Seven  Alternative Freeride
#
#             Riding Level                Shape      Camber Profile  \
# 14       Advanced-Expert  Tapered Directional   Continuous Rocker
# 43       Advanced-Expert  Tapered Directional       Mostly Camber
# 59       Advanced-Expert  Tapered Directional  Directional Camber
# 65   Intermediate-Expert  Tapered Directional       Hybrid Rocker
# 66       Advanced-Expert  Tapered Directional  Directional Camber
# 68       Beginner-Expert  Tapered Directional       Hybrid Rocker
# 80       Advanced-Expert  Tapered Directional  Directional Camber
# 86       Advanced-Expert  Tapered Directional  Directional Camber
# 133  Intermediate-Expert  Tapered Directional       Hybrid Camber
# 134      Advanced-Expert  Tapered Directional  Directional Camber
# 138      Advanced-Expert  Tapered Directional       Hybrid Camber
# 139      Advanced-Expert  Tapered Directional       Hybrid Camber
# 156      Advanced-Expert  Tapered Directional  Directional Camber
# 157      Advanced-Expert  Tapered Directional  Directional Camber
# 159      Beginner-Expert  Tapered Directional       Mostly Camber
# 161      Advanced-Expert  Tapered Directional       Mostly Camber
# 162      Beginner-Expert  Tapered Directional       Hybrid Rocker
# 182      Advanced-Expert  Tapered Directional       Mostly Camber
# 197      Advanced-Expert  Tapered Directional  Directional Camber
# 198      Advanced-Expert  Tapered Directional  Directional Camber
# 199      Advanced-Expert  Tapered Directional       Hybrid Camber
# 224      Advanced-Expert  Tapered Directional       Hybrid Camber
# 266      Advanced-Expert  Tapered Directional  Directional Camber
# 270      Advanced-Expert  Tapered Directional       Mostly Camber
# 273  Intermediate-Expert  Tapered Directional       Hybrid Rocker
# 299  Intermediate-Expert  Tapered Directional       Mostly Camber
# 321  Intermediate-Expert  Tapered Directional       Hybrid Camber
# 322      Advanced-Expert  Tapered Directional       Hybrid Camber
# 334      Advanced-Expert  Tapered Directional  Directional Camber
# 356      Advanced-Expert  Tapered Directional       Mostly Camber
# 380      Advanced-Expert  Tapered Directional  Directional Camber
#
#                 Stance          Flex  Price($)     Powder
# 14            Centered        Medium       599      Great
# 43            Centered        Medium       479      Great
# 59   Setback over 20mm  Medium/Stiff       399      Great
# 65   Setback over 20mm  Medium/Stiff       649      Great
# 66   Setback over 20mm        Medium       449      Great
# 68   Setback over 20mm  Medium/Stiff       999      Great
# 80   Setback over 20mm        Medium       499       Good
# 86   Setback over 20mm  Medium/Stiff       579      Great
# 133           Centered         Stiff       699      Great
# 134  Setback over 20mm  Medium/Stiff       699      Great
# 138  Setback over 20mm  Medium/Stiff       649  Excellent
# 139      Setback -20mm  Medium/Stiff       549  Excellent
# 156  Setback over 20mm  Medium/Stiff       449      Great
# 157    Setback -12.5mm  Medium/Stiff       549      Great
# 159  Setback over 20mm  Medium/Stiff       549       Good
# 161  Setback over 20mm        Medium       599       Good
# 162  Setback over 20mm        Medium       599       Good
# 182  Setback over 20mm  Medium/Stiff       599      Great
# 197      Setback -20mm  Medium/Stiff       559      Great
# 198      Setback -20mm  Medium/Stiff       479      Great
# 199      Setback -20mm  Medium/Stiff       599       Good
# 224  Setback over 20mm  Medium/Stiff       799  Excellent
# 266  Setback over 20mm  Medium/Stiff       499       Good
# 270  Setback over 20mm  Medium/Stiff       549       Good
# 273  Setback over 20mm  Medium/Stiff       619       Good
# 299           Centered  Medium/Stiff       499       Good
# 321           Centered        Medium       649       Good
# 322  Setback over 20mm        Medium       459  Excellent
# 334  Setback over 20mm  Medium/Stiff       599      Great
# 356  Setback over 20mm  Medium/Stiff       599       Good
# 380      Setback -20mm        Medium       549      Great

# %%
alternative_fr_shapes = pd.DataFrame(alternative_fr_boards['Shape'].value_counts())

# %%
plt.figure(figsize=(10,6))
alternative_fr_shapes.plot(kind='bar', color='#09b0b8')
plt.title('Alternative Freeride Snowboard Shapes')
plt.xlabel('')
plt.ylabel('Number of Boards')
# Out:
# Text(0, 0.5, 'Number of Boards')

# %%
alternative_fr_camber = alternative_fr_boards['Camber Profile'].value_counts()
alternative_fr_camber
# Out:
# Camber Profile
# Directional Camber    12
# Mostly Camber          7
# Hybrid Camber          7
# Hybrid Rocker          4
# Continuous Rocker      1
# Name: count, dtype: int64

# %% [markdown]
# Majority of the alternative freeride boards are camber while a few are rocker.

# %%
alternative_fr_flex = alternative_fr_boards['Flex'].value_counts()
alternative_fr_flex
# Out:
# Flex
# Medium/Stiff    21
# Medium           9
# Stiff            1
# Name: count, dtype: int64

# %% [markdown]
# Majority of the alternative freeride boards have a medium and stiff flex.

# %% [markdown]
# ## Freeride Snowboards

# %%
freeride_boards = snowboards[snowboards['Riding Style'] == 'Freeride']
freeride_boards
# Out:
#         Brand                  Model Riding Style         Riding Level  \
# 1          K2             Instrument     Freeride  Intermediate-Expert
# 3          K2              Alchemist     Freeride      Advanced-Expert
# 18     Burton              First Cut     Freeride      Advanced-Expert
# 19     Burton           Deep Thinker     Freeride      Advanced-Expert
# 36   Lib Tech                    BRD     Freeride  Intermediate-Expert
# 60       Rome          Ravine Select     Freeride      Advanced-Expert
# 61       Rome                 Ravine     Freeride      Advanced-Expert
# 67   Lib Tech            Golden Orca     Freeride      Beginner-Expert
# 70        Gnu         Banked Country     Freeride      Advanced-Expert
# 72      Arbor                 Clovis     Freeride      Beginner-Expert
# 78     Burton           Skeleton Key     Freeride      Advanced-Expert
# 79     Burton          Hometown Hero     Freeride      Advanced-Expert
# 82     Burton        3D Daily Driver     Freeride  Intermediate-Expert
# 83     Burton             Instigator     Freeride      Beginner-Expert
# 84     Burton            Wave Tracer     Freeride      Beginner-Expert
# 85     Burton          3D Double Dog     Freeride      Advanced-Expert
# 92      Jones              Project X     Freeride  Intermediate-Expert
# 132     Jones               Flagship     Freeride      Advanced-Expert
# 135     Jones         Ultra Flagship     Freeride      Advanced-Expert
# 144     Arbor        Crosscut Camber     Freeride      Advanced-Expert
# 145     Arbor                  Annex     Freeride      Advanced-Expert
# 151    Burton        Straight Chuter     Freeride      Advanced-Expert
# 152    Burton                 Sensei     Freeride      Advanced-Expert
# 158  Lib Tech          MC Snake Kink     Freeride      Advanced-Expert
# 178     Jones                Stratos     Freeride  Intermediate-Expert
# 181    Burton            Super Bueno     Freeride      Advanced-Expert
# 265    Burton           Leader Board     Freeride      Beginner-Expert
# 267     Jones        Carbon Flagship     Freeride      Advanced-Expert
# 269       Gnu                Mullair     Freeride      Advanced-Expert
# 272  Lib Tech            Swiss Knife     Freeride      Advanced-Expert
# 275  Lib Tech      Jamie Lynn Dagmar     Freeride      Beginner-Expert
# 276  Lib Tech              Cold Brew     Freeride      Beginner-Expert
# 279  Lib Tech  Jamie Lynn Titty Fish     Freeride      Advanced-Expert
# 291   Salomon           Taka X Wolle     Freeride  Intermediate-Expert
# 298    Burton       Flight Attendant     Freeride      Advanced-Expert
# 300  Lib Tech   Lost Round Nose Fish     Freeride      Advanced-Expert
# 301     Arbor                A-Frame     Freeride      Advanced-Expert
# 320   Salomon               Speedway     Freeride      Advanced-Expert
# 323   Salomon                Super 8     Freeride      Advanced-Expert
# 335    Burton             Speed Date     Freeride      Advanced-Expert
# 345  Lib Tech      Doughboy Shredder     Freeride               Expert
# 349  Lib Tech            Ejack Knife     Freeride      Advanced-Expert
# 352       Gnu                 SPASYM     Freeride      Advanced-Expert
# 355       Gnu            Hyperkyarve     Freeride      Beginner-Expert
# 376    Capita        Kazu Kokubo Pro     Freeride      Advanced-Expert
# 385        K2              Broadcast     Freeride  Intermediate-Expert
#
#                    Shape      Camber Profile             Stance          Flex  \
# 1    Tapered Directional  Directional Camber      Setback -20mm  Medium/Stiff
# 3    Tapered Directional  Directional Camber      Setback -20mm  Medium/Stiff
# 18   Tapered Directional  Directional Camber      Setback -20mm         Stiff
# 19   Tapered Directional  Directional Camber  Setback over 20mm   Medium/Soft
# 36   Tapered Directional       Hybrid Camber  Setback over 20mm        Medium
# 60   Tapered Directional  Directional Camber      Setback -20mm  Medium/Stiff
# 61   Tapered Directional  Directional Camber      Setback -20mm        Medium
# 67   Tapered Directional       Hybrid Rocker  Setback over 20mm        Medium
# 70   Tapered Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 72   Tapered Directional       Mostly Camber           Centered        Medium
# 78   Tapered Directional  Directional Camber  Setback over 20mm        Medium
# 79   Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 82   Tapered Directional  Directional Camber  Setback over 20mm        Medium
# 83   Tapered Directional      Flat to Rocker  Setback over 20mm  Medium/Stiff
# 84   Tapered Directional       Hybrid Rocker  Setback over 20mm        Medium
# 85   Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 92   Tapered Directional  Directional Camber      Setback -20mm  Medium/Stiff
# 132  Tapered Directional       Hybrid Camber  Setback over 20mm  Medium/Stiff
# 135  Tapered Directional       Hybrid Camber  Setback over 20mm         Stiff
# 144  Tapered Directional       Mostly Camber      Setback -10mm  Medium/Stiff
# 145  Tapered Directional       Mostly Camber      Setback -10mm         Stiff
# 151  Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 152          Directional  Traditional Camber      Setback -20mm  Medium/Stiff
# 158  Tapered Directional       Mostly Camber  Setback over 20mm        Medium
# 178  Tapered Directional       Hybrid Camber      Setback -20mm  Medium/Stiff
# 181  Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 265  Tapered Directional  Directional Camber  Setback over 20mm         Stiff
# 267  Tapered Directional       Hybrid Camber  Setback over 20mm         Stiff
# 269  Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 272  Tapered Directional       Mostly Camber           Centered  Medium/Stiff
# 275  Tapered Directional       Hybrid Rocker  Setback over 20mm  Medium/Stiff
# 276  Tapered Directional       Hybrid Rocker  Setback over 20mm        Medium
# 279  Tapered Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 291  Tapered Directional  Directional Camber  Setback over 20mm        Medium
# 298  Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 300  Tapered Directional       Hybrid Rocker  Setback over 20mm  Medium/Stiff
# 301  Tapered Directional       Mostly Camber      Setback -10mm         Stiff
# 320  Tapered Directional       Mostly Camber      Setback -20mm        Medium
# 323  Tapered Directional  Directional Camber      Setback -15mm        Medium
# 335  Tapered Directional  Directional Camber  Setback over 20mm  Medium/Stiff
# 345          Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 349  Tapered Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 352  Tapered Directional       Mostly Camber  Setback over 20mm  Medium/Stiff
# 355  Tapered Directional       Hybrid Camber  Setback over 20mm        Medium
# 376  Tapered Directional  Directional Camber    Setback -12.5mm  Medium/Stiff
# 385  Tapered Directional       Hybrid Camber      Setback -20mm        Medium
#
#      Price($)   Powder
# 1         529    Great
# 3         699     Good
# 18        559     Good
# 19        629     Good
# 36        629    Great
# 60        629     Good
# 61        529     Good
# 67        749     Good
# 70        529     Good
# 72        549     Good
# 78        549    Great
# 79        629     Good
# 82        629     Good
# 83        419     Good
# 84        629    Great
# 85        629     Good
# 92       1699    Great
# 132       649    Great
# 135       999    Great
# 144       499     Good
# 145       699     Good
# 151       749    Great
# 152       649     Good
# 158       599     Good
# 178       599    Great
# 181       599     Good
# 265       549     Good
# 267       999     Good
# 269       599     Good
# 272       599  Average
# 275       579     Good
# 276       459     Good
# 279       599     Good
# 291       649     Good
# 298       609     Good
# 300       649     Good
# 301       649     Good
# 320       599     Good
# 323       449     Good
# 335       650     Good
# 345       749     Good
# 349       599  Average
# 352       599     Good
# 355       519     Good
# 376       559  Average
# 385       449     Good

# %%
freeride_shapes = pd.DataFrame(freeride_boards['Shape'].value_counts())

# %%
plt.figure(figsize=(10,6))
freeride_shapes.plot(kind='bar', color='#110b97')
plt.title('Freeride Snowboard Shapes')
plt.xlabel('')
plt.ylabel('Number of Boards')
# Out:
# Text(0, 0.5, 'Number of Boards')

# %%
freeride_camber = freeride_boards['Camber Profile'].value_counts()
freeride_camber
# Out:
# Camber Profile
# Directional Camber    20
# Mostly Camber         12
# Hybrid Camber          7
# Hybrid Rocker          5
# Flat to Rocker         1
# Traditional Camber     1
# Name: count, dtype: int64

# %% [markdown]
# Majority of the freeride boards are camber while a few are rocker.

# %%
freeride_flex = freeride_boards['Flex'].value_counts()
freeride_flex
# Out:
# Flex
# Medium/Stiff    25
# Medium          14
# Stiff            6
# Medium/Soft      1
# Name: count, dtype: int64

# %% [markdown]
# Similar to alternative freeride boards, a majority of the freeride boards have a medium and stiff flex.

# %% [markdown]
# ## Powder Snowboards

# %%
powder_boards = snowboards[snowboards['Riding Style'] == 'Powder']
powder_boards
# Out:
#       Brand                                     Model Riding Style  \
# 28   Capita                  Spring Break Powder Pill       Powder
# 29   Capita                Spring Break Powder Glider       Powder
# 88   Burton                                   3D Fish       Powder
# 91    Jones                              Storm Chaser       Powder
# 117  Capita                                 Navigator       Powder
# 118  Capita                              Spring Break       Powder
# 127  Capita                       Spring Break Powder       Powder
# 153  Burton                                Pow Wrench       Powder
# 239  Capita                Spring Break Slush Slasher       Powder
# 240  Capita                 Spring Break Powder Racer       Powder
# 241  Capita               Spring Break Powder Drifter       Powder
# 242  Capita        Spring Break Powder 167 Night Hawk       Powder
# 243  Capita  Spring Break Powder 151 Mini Tree Hunter       Powder
# 296  Capita       Spring Break Powder 161 Tree Hunter       Powder
# 383      K2                             Party Platter       Powder
# 384      K2                                 Cool Bean       Powder
#
#             Riding Level                Shape      Camber Profile  \
# 28   Intermediate-Expert  Tapered Directional      Flat to Rocker
# 29   Intermediate-Expert  Tapered Directional      Flat to Rocker
# 88   Intermediate-Expert  Tapered Directional      Flat to Rocker
# 91       Advanced-Expert  Tapered Directional      Flat to Rocker
# 117  Intermediate-Expert  Tapered Directional  Directional Camber
# 118      Beginner-Expert  Tapered Directional      Flat to Rocker
# 127      Advanced-Expert            True Twin       Hybrid Camber
# 153  Intermediate-Expert  Tapered Directional      Flat to Rocker
# 239  Intermediate-Expert  Tapered Directional      Flat to Rocker
# 240      Beginner-Expert  Tapered Directional      Flat to Rocker
# 241  Intermediate-Expert  Tapered Directional      Flat to Rocker
# 242      Advanced-Expert  Tapered Directional      Flat to Rocker
# 243  Intermediate-Expert  Tapered Directional      Flat to Rocker
# 296      Advanced-Expert  Tapered Directional      Flat to Rocker
# 383  Intermediate-Expert  Tapered Directional      Flat to Rocker
# 384      Advanced-Expert  Tapered Directional      Flat to Rocker
#
#                 Stance          Flex  Price($)     Powder
# 28   Setback over 20mm  Medium/Stiff       899  Excellent
# 29   Setback over 20mm        Medium       899  Excellent
# 88   Setback over 20mm        Medium       629  Excellent
# 91     Setback -12.5mm  Medium/Stiff       599  Excellent
# 117  Setback over 20mm        Medium       449       Good
# 118           Centered          Soft       729  Excellent
# 127           Centered  Medium/Stiff       479      Great
# 153      Setback -20mm        Medium       529      Great
# 239  Setback over 20mm        Medium       379      Great
# 240  Setback over 20mm   Medium/Soft       499      Great
# 241  Setback over 20mm   Medium/Soft       719      Great
# 242  Setback over 20mm  Medium/Stiff       719  Excellent
# 243  Setback over 20mm        Medium       719      Great
# 296  Setback over 20mm  Medium/Stiff       749  Excellent
# 383  Setback over 20mm  Medium/Stiff       449      Great
# 384  Setback over 20mm  Medium/Stiff       469  Excellent

# %%
powder_shapes = pd.DataFrame(powder_boards['Shape'].value_counts())

# %%
plt.figure(figsize=(10,6))
powder_shapes.plot(kind='bar', color='#1673c5')
plt.title('Powder Snowboard Shapes')
plt.xlabel('')
plt.ylabel('Number of Boards')
# Out:
# Text(0, 0.5, 'Number of Boards')

# %%
powder_camber = powder_boards['Camber Profile'].value_counts()
powder_camber
# Out:
# Camber Profile
# Flat to Rocker        14
# Directional Camber     1
# Hybrid Camber          1
# Name: count, dtype: int64

# %% [markdown]
# Majority of the powder boards are flat to rocker. Very few are camber.

# %%
powder_flex = powder_boards['Flex'].value_counts()
powder_flex
# Out:
# Flex
# Medium/Stiff    7
# Medium          6
# Medium/Soft     2
# Soft            1
# Name: count, dtype: int64

# %% [markdown]
# Majority of powder boards have a medium flex.
